# %% [markdown]
# ## **Dictionary**
#
# - Dict bao gồm các cặp key:value
# - key thường là "character"
# - value thường chứa các "element"
# - ![image.png](attachment:c5b0bbf8-b473-4f01-a389-9a4614556d3f.png)
